# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
flight = r'C:\Users\COMP\Desktop\Xylos\train.csv'
flight = pd.read_csv(flight)
flight.head()
# Out:
#      Airline Date_of_Journey    Source Destination            Route Dep_Time  \
# 0  Airline C      12/06/2019     Delhi      Cochin  DEL → MAA → COK    20:40
# 1  Airline A      18/06/2019  Banglore       Delhi        BLR → DEL    18:55
# 2  Airline C      18/05/2019     Delhi      Cochin  DEL → BOM → COK    03:50
# 3  Airline A       6/05/2019   Kolkata    Banglore  CCU → BOM → BLR    20:00
# 4  Airline A       9/05/2019   Kolkata    Banglore  CCU → BOM → BLR    06:30
#
#    Arrival_Time Duration Total_Stops              Additional_Info  Price
# 0  09:25 13 Jun  12h 45m      1 stop                      No info   7480
# 1         22:00    3h 5m    non-stop                      No info   8016
# 2         19:15  15h 25m      1 stop                      No info   8879
# 3  08:15 07 May  12h 15m      1 stop  In-flight meal not included   9663
# 4         12:00   5h 30m      1 stop  In-flight meal not included   9663

# %%
flight.shape
# Out:
# (8012, 11)

# %%
flight.describe()
# Out:
#               Price
# count   8012.000000
# mean    9062.037943
# std     4626.593069
# min     1759.000000
# 25%     5277.000000
# 50%     8371.000000
# 75%    12373.000000
# max    79512.000000

# %%
flight.describe(exclude=np.number)
# Out:
#           Airline Date_of_Journey Source Destination            Route  \
# count        8012            8012   8012        8012             8011
# unique         12              44      5           6              122
# top     Airline A       6/06/2019  Delhi      Cochin  DEL → BOM → COK
# freq         2881             390   3398        3398             1784
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count      8012         8012     8012        8011            8012
# unique      219         1182      353           4              10
# top       18:55        19:00   2h 50m      1 stop         No info
# freq        189          303      412        4235            6251

# %%
flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
(flight[flight["Total_Stops"].isnull()])
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 1807  Airline C       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 1807  09:25 07 May  23h 40m         NaN         No info   7480

# %%
(flight[flight["Route"].isnull()])
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 1807  Airline C       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 1807  09:25 07 May  23h 40m         NaN         No info   7480

# %%
flight[(flight["Duration"]=="23h 40m")].groupby(["Route"])["Duration"].count()
# Out:
# Route
# BLR → BOM → DEL          5
# BLR → GOI → DEL          1
# DEL → AMD → BOM → COK    5
# DEL → HYD → MAA → COK    9
# DEL → MAA → COK          8
# Name: Duration, dtype: int64

# %%
(flight[flight["Route"]=="DEL → HYD → MAA → COK"])
# Out:
#         Airline Date_of_Journey Source Destination                  Route  \
# 55    Airline B       6/03/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 110   Airline C      15/06/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 528   Airline C       9/05/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 617   Airline C       1/06/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 637   Airline C      27/06/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 710   Airline B       3/03/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 768   Airline D       6/03/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 834   Airline C      15/06/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 906   Airline B      21/03/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 1033  Airline C       6/03/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 1193  Airline B       1/03/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# 1254  Airline C      24/06/2019  Delhi      Cochin  DEL → HYD → MAA → COK
# ...

# %%
flight["Airline"].value_counts()
# Out:
# Airline A    2881
# Airline B    1550
# Airline C    1287
# Airline D     906
# Airline E     625
# Airline F     360
# Airline G     235
# Airline H     146
# Airline I      12
# Airline J       6
# Airline K       3
# Airline L       1
# Name: Airline, dtype: int64

# %%
(flight[flight["Airline"]=="Airline A"]).groupby("Route")["Airline"].count().sort_values(ascending=False)
# Out:
# Route
# CCU → BOM → BLR          715
# DEL → BOM → COK          633
# BLR → DEL                292
# BLR → BOM → DEL          286
# CCU → DEL → BLR          233
# BOM → HYD                152
# DEL → JAI → BOM → COK    150
# DEL → AMD → BOM → COK    100
# DEL → IDR → BOM → COK     60
# DEL → NAG → BOM → COK     51
# DEL → ATQ → BOM → COK     28
# DEL → COK                 24
# DEL → BHO → BOM → COK     22
# DEL → LKO → BOM → COK     21
# DEL → BDQ → BOM → COK     20
# CCU → GAU → BLR           19
# DEL → JDH → BOM → COK     17
# DEL → MAA → BOM → COK     14
# DEL → IXC → BOM → COK     12
# BLR → MAA → DEL            7
# DEL → UDR → BOM → COK      5
# BOM → DEL → HYD            4
# CCU → BOM → PNQ → BLR      3
# BLR → BOM → JDH → DEL      3
# DEL → DED → BOM → COK      2
# BLR → BDQ → DEL            2
# BOM → JDH → DEL → HYD      1
# BOM → IDR → DEL → HYD      1
# BOM → UDR → DEL → HYD      1
# BOM → DED → DEL → HYD      1
# BOM → BDQ → DEL → HYD      1
# BOM → VNS → DEL → HYD      1
# ...
